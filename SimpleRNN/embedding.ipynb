# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# d:\Projects\End to End DL project with RNN\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
sent=['I love my dog',
      'I love my cat',
      'You love my dog!',
      'Do you think my dog is amazing?',
      'My dog loves me more than you',
      'i am happy to see you',
      'you are my best friend'
    ]

# %%
sent
# Out:
# ['I love my dog',
#  'I love my cat',
#  'You love my dog!',
#  'Do you think my dog is amazing?',
#  'My dog loves me more than you',
#  'i am happy to see you',
#  'you are my best friend']

# %%
voc_size=10000

# %%
one_hot_repr = [one_hot(words, voc_size) for words in sent]
one_hot_repr
# Out:
# [[9298, 1571, 8059, 4672],
#  [9298, 1571, 8059, 5312],
#  [3733, 1571, 8059, 4672],
#  [257, 3733, 4282, 8059, 4672, 4844, 2121],
#  [8059, 4672, 7345, 8285, 1738, 1534, 3733],
#  [9298, 7223, 3385, 8163, 1570, 3733],
#  [3733, 4047, 8059, 6999, 9712]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 9298 1571 8059 4672]
#  [   0    0    0    0 9298 1571 8059 5312]
#  [   0    0    0    0 3733 1571 8059 4672]
#  [   0  257 3733 4282 8059 4672 4844 2121]
#  [   0 8059 4672 7345 8285 1738 1534 3733]
#  [   0    0 9298 7223 3385 8163 1570 3733]
#  [   0    0    0 3733 4047 8059 6999 9712]]

# %%
dim =10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim, input_length=sent_length))
model.compile('adam','mse')
# Out:
# d:\Projects\End to End DL project with RNN\venv\Lib\site-packages\keras\src\layers\core\embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# array([[[-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.02762136,  0.00669581,  0.0427664 ,  0.0207347 ,
#           0.01363096,  0.04419104, -0.0055756 , -0.00271752,
#           0.02266109,  0.04178664],
#         [ 0.03713248, -0.04516014,  0.01292406,  0.00098771,
#           0.00921316, -0.02660872,  0.04578711,  0.02068653,
#           0.02496136,  0.03785679],
#         [-0.01369029,  0.02808483,  0.02988559,  0.01943681,
#           0.01092722,  0.03836545, -0.04989121, -0.04468047,
#           0.01788123, -0.02056885],
#         [ 0.04756761,  0.03573814, -0.04329799, -0.02928658,
#           0.02150479, -0.04559572, -0.03767476, -0.02908827,
#           0.01751589, -0.01248912]],
#
#        [[-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.02762136,  0.00669581,  0.0427664 ,  0.0207347 ,
#           0.01363096,  0.04419104, -0.0055756 , -0.00271752,
#           0.02266109,  0.04178664],
#         [ 0.03713248, -0.04516014,  0.01292406,  0.00098771,
#           0.00921316, -0.02660872,  0.04578711,  0.02068653,
#           0.02496136,  0.03785679],
#         [-0.01369029,  0.02808483,  0.02988559,  0.01943681,
#           0.01092722,  0.03836545, -0.04989121, -0.04468047,
#           0.01788123, -0.02056885],
#         [-0.03831803,  0.03951539, -0.03499668, -0.00042129,
#          -0.03827307,  0.02103791, -0.01791127,  0.04301075,
#          -0.03497232,  0.04877279]],
#
#        [[-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [ 0.02547893,  0.00236898, -0.02084012,  0.03595269,
#           0.01148199, -0.00804616,  0.01826939, -0.02308967,
#          -0.00316094,  0.01969815],
#         [ 0.03713248, -0.04516014,  0.01292406,  0.00098771,
#           0.00921316, -0.02660872,  0.04578711,  0.02068653,
#           0.02496136,  0.03785679],
#         [-0.01369029,  0.02808483,  0.02988559,  0.01943681,
#           0.01092722,  0.03836545, -0.04989121, -0.04468047,
#           0.01788123, -0.02056885],
#         [ 0.04756761,  0.03573814, -0.04329799, -0.02928658,
#           0.02150479, -0.04559572, -0.03767476, -0.02908827,
#           0.01751589, -0.01248912]],
#
#        [[-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [ 0.01251233, -0.01119095,  0.00450069,  0.00506852,
#           0.03958109, -0.02138206, -0.01483266, -0.02022508,
#           0.03631439, -0.00721771],
#         [ 0.02547893,  0.00236898, -0.02084012,  0.03595269,
#           0.01148199, -0.00804616,  0.01826939, -0.02308967,
#          -0.00316094,  0.01969815],
#         [ 0.04311719,  0.00955262,  0.02700113,  0.01681509,
#          -0.003899  ,  0.03691933, -0.02280958, -0.0471162 ,
#          -0.03940696, -0.02009097],
#         [-0.01369029,  0.02808483,  0.02988559,  0.01943681,
#           0.01092722,  0.03836545, -0.04989121, -0.04468047,
#           0.01788123, -0.02056885],
#         [ 0.04756761,  0.03573814, -0.04329799, -0.02928658,
#           0.02150479, -0.04559572, -0.03767476, -0.02908827,
#           0.01751589, -0.01248912],
#         [-0.00878391,  0.02685058, -0.03663141,  0.03228512,
#          -0.00829424, -0.022694  , -0.03852794, -0.04710926,
#           0.04363898, -0.03226066],
#         [ 0.00990387, -0.00934974,  0.03145262,  0.0110077 ,
#           0.00052804, -0.04607762, -0.00109114,  0.04844369,
#           0.01611985, -0.01261222]],
#
#        [[-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.01369029,  0.02808483,  0.02988559,  0.01943681,
#           0.01092722,  0.03836545, -0.04989121, -0.04468047,
#           0.01788123, -0.02056885],
#         [ 0.04756761,  0.03573814, -0.04329799, -0.02928658,
#           0.02150479, -0.04559572, -0.03767476, -0.02908827,
#           0.01751589, -0.01248912],
#         [ 0.04985308, -0.03929123, -0.00474761,  0.014458  ,
#          -0.02780404, -0.03854952,  0.00092036, -0.01691454,
#          -0.02586384,  0.04361972],
#         [-0.00274074,  0.00814012,  0.02242824, -0.04303766,
#          -0.00874553, -0.01796633,  0.03047499, -0.00077572,
#           0.00737087, -0.03011878],
#         [ 0.03812485, -0.00845402, -0.02898324,  0.03268431,
#           0.04354693,  0.03292462,  0.03942746,  0.01159807,
#          -0.01122581, -0.01330882],
#         [ 0.03856606, -0.01898211, -0.04853708,  0.00676399,
#           0.03899303,  0.03182609,  0.02923277,  0.03074795,
#          -0.03358886,  0.00549154],
#         [ 0.02547893,  0.00236898, -0.02084012,  0.03595269,
#           0.01148199, -0.00804616,  0.01826939, -0.02308967,
#          -0.00316094,  0.01969815]],
#
#        [[-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.02762136,  0.00669581,  0.0427664 ,  0.0207347 ,
#           0.01363096,  0.04419104, -0.0055756 , -0.00271752,
#           0.02266109,  0.04178664],
#         [-0.01325784, -0.02757314,  0.01730797,  0.03338749,
#          -0.01243903, -0.02929119,  0.04454932,  0.04252743,
#           0.00457591,  0.01449188],
#         [-0.02991139,  0.04199317,  0.01863405,  0.02987573,
#           0.01289756,  0.03471563,  0.00714882, -0.0040595 ,
#          -0.04629574, -0.02779046],
#         [-0.02394636,  0.04332617,  0.00661363, -0.02665933,
#          -0.04979668, -0.01285986, -0.00423945,  0.03012684,
#          -0.00429591, -0.02457898],
#         [ 0.02047578,  0.01862064, -0.00869821,  0.03592706,
#           0.02252635, -0.03077427,  0.03963671,  0.0152069 ,
#           0.03877247,  0.04225974],
#         [ 0.02547893,  0.00236898, -0.02084012,  0.03595269,
#           0.01148199, -0.00804616,  0.01826939, -0.02308967,
#          -0.00316094,  0.01969815]],
#
#        [[-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [ 0.02547893,  0.00236898, -0.02084012,  0.03595269,
#           0.01148199, -0.00804616,  0.01826939, -0.02308967,
#          -0.00316094,  0.01969815],
#         [-0.01606866, -0.03855722,  0.02389551,  0.0177662 ,
#          -0.01672091, -0.0157779 ,  0.00855601,  0.04945782,
#          -0.02688644,  0.04729294],
#         [-0.01369029,  0.02808483,  0.02988559,  0.01943681,
#           0.01092722,  0.03836545, -0.04989121, -0.04468047,
#           0.01788123, -0.02056885],
#         [-0.02466749,  0.04755851,  0.02248624, -0.04187944,
#           0.02055556,  0.00686368,  0.02086836, -0.01304235,
#          -0.03774131, -0.0224916 ],
#         [-0.03425194, -0.03593353, -0.0352214 , -0.03387608,
#           0.00248647, -0.0219514 , -0.02914019, -0.00660621,
#          -0.01500507,  0.03619668]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 9298, 1571, 8059, 4672], dtype=int32)

# %%
model.predict(embedded_docs[0].reshape(1, sent_length))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# array([[[-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.0414582 ,  0.03496604,  0.0397144 , -0.0062579 ,
#           0.04571408, -0.01696432, -0.01221417, -0.00130786,
#          -0.04598179,  0.03813017],
#         [-0.02762136,  0.00669581,  0.0427664 ,  0.0207347 ,
#           0.01363096,  0.04419104, -0.0055756 , -0.00271752,
#           0.02266109,  0.04178664],
#         [ 0.03713248, -0.04516014,  0.01292406,  0.00098771,
#           0.00921316, -0.02660872,  0.04578711,  0.02068653,
#           0.02496136,  0.03785679],
#         [-0.01369029,  0.02808483,  0.02988559,  0.01943681,
#           0.01092722,  0.03836545, -0.04989121, -0.04468047,
#           0.01788123, -0.02056885],
#         [ 0.04756761,  0.03573814, -0.04329799, -0.02928658,
#           0.02150479, -0.04559572, -0.03767476, -0.02908827,
#           0.01751589, -0.01248912]]], dtype=float32)
